# %%
from matplotlib import pyplot as plt
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
plt.plot(years, gdp, color="green", marker="o", linestyle="solid")
plt.title("Nominal GDP")
plt.ylabel("Billions of $")
plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]
xs = [i+0.5 for i, _ in enumerate(movies)]
plt.bar(xs, num_oscars)
plt.ylabel("# of Academy Awards")
plt.title("My Favorite Movies")
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)
plt.show()

# %%
from collections import Counter
grades = [83,95,91,87,70,0,85,82,100,67,73,77,0]
decile = lambda grade: grade // 10 * 10
histogram = Counter(decile(grade) for grade in grades)
plt.bar([x - 4 for x in histogram.keys()], histogram.values(), 8)
plt.axis([-5, 105, 0, 5]) # x-axis from -5 to 105, y-axis from 0 to 5
plt.xticks([10 * i for i in range(11)]) # x-axis labels at 0, 10, ..., 100
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %%
mentions = [500, 505]
years = [2013, 2014]
plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")
plt.ticklabel_format(useOffset=False)
plt.axis([2012.5,2014.5,499,506])
plt.title("Look at the 'Huge' Increase!")
plt.show()

# %%
from matplotlib import pyplot as plt
input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]
plt.plot(input_values, squares, linewidth = 5)
plt.title("Square Numbers", fontsize = 18)
plt.xlabel("Value", fontsize = 12)
plt.ylabel("Square of Value", fontsize = 12)
plt.tick_params(axis = "both", labelsize = 12)
#plt.show()
plt.savefig('squares_plot.png', bbox_inches='tight')

# %%
plt.scatter(2, 4, s = 200)
plt.title("Square Numbers", fontsize=18)
plt.xlabel("Value", fontsize=12)
plt.ylabel("Square of Value", fontsize=12)
# Set size of tick labels.
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()

# %%
from matplotlib import pyplot as plt
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16, 25]
plt.scatter(x_values, y_values, s=100)

# %%
from matplotlib import pyplot as plt
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]
#plt.scatter(x_values, y_values, c = y_values, cmap = "terrain", s = 40)
plt.scatter(x_values, y_values, c = y_values, cmap = plt.cm.Blues, s = 40)
plt.axis([0, 1100, 0, 1100000])
# Out:
# (0.0, 1100.0, 0.0, 1100000.0)

# %%
import matplotlib.pyplot as plt
input_values = [1, 2, 3, 4, 5]
square = [1, 4, 9, 16, 25]
plt.plot(input_values, square, linewidth = 5)
plt.title("Square Numbers", fontsize = 18)
plt.xlabel("Value")
plt.ylabel("Square of Value")
plt.tick_params(axis = "both", direction = "inout", length = 8, width = 2, pad = 10, right = True, labelrotation = 25, 
                grid_color = "springgreen", labelsize = "large", colors = "red")
plt.show()

# %%
plt.scatter(2, 4, s = 200, c = "red", marker = "D", linewidths = 1.5, alpha = 0.5, edgecolors = "blue")
plt.title("Square Numbers", fontsize = 12)
plt.xlabel("Value", fontsize = 10)
plt.ylabel("Square of Value", fontsize = 10)
plt.tick_params(axis = "both")
plt.show()

# %%
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.4.1

# %%
import matplotlib
print(format(matplotlib.__version__))
# Out:
# 3.4.1

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.4.1

# %%
import matplotlib.pyplot as plt
#import numpy as np

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x, y)

x = [2,2,8,1,15,8,12,9,7,3,11,4,7,14,12]
y = [100,105,84,105,90,99,90,95,94,100,79,112,91,80,85]
plt.scatter(x, y)

plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
#colors = ["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"]
colors = [1.1, 1.9, 3.33, 4.66, 9, 6.6, 7.7, 8.8, 9.9, 0.1, 0.9, 0.55, 0.77]
plt.scatter(x, y, c=colors, cmap = "terrain")
plt.colorbar()
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
colors = ["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"]

plt.scatter(x, y, c=colors)
# cmap='viridis' by default
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))
sizes = 10 * np.random.randint(100, size = (100)) 
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()                       
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, "o:r")
plt.show()

# %%
import matplotlib.pyplot as plt

ypoints = [3, 8, 1, 10]
plt.plot(ypoints, marker = 'o', ms = 20, mec = "navy", mfc = "springgreen")
plt.show()

# %%
ypoints = [3, 8, 1, 10]
plt.plot(ypoints, linestyle = "dashed", c = "hotpink", linewidth = 5) #short:ls = "--" and lw = 5
plt.show()

# %%
y1 = [3, 8, 1, 10]
y2 = [6, 2, 7, 11]
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
x = [80, 85, 90, 95, 100, 105, 110, 115, 120, 125]
y = [240, 250, 260, 270, 280, 290, 300, 310, 320, 330]

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc = "left")
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.grid(axis = "both", color = 'green', linestyle = ':', linewidth = 0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hsv', alpha=0.75)

# %%
from matplotlib import pyplot as plt
x_values = list(range(1, 1001))
y_values = [x**3 for x in x_values]
#plt.scatter(x_values, y_values, c = y_values, cmap = plt.cm.Blues, s = 40)
plt.plot(x_values, y_values)
plt.axis([0, 1100, 0, 1100000])
# Out:
# (0.0, 1100.0, 0.0, 1100000.0)
